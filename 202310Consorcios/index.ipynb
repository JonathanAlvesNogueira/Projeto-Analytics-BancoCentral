# %%
import pandas as pd 
import numpy as np

url = "C:/Users/joth1/Documents/miniprojeto_pandas_sql/Nova pasta/202310Consorcios/202310Bens_Imoveis_Grupos.csv"

# Tente ler o arquivo usando utf-8 e, se falhar, tente latin-1
try:
    df = pd.read_csv(url, encoding='utf-8', sep=';')
except UnicodeDecodeError:
    df = pd.read_csv(url, encoding='latin-1', sep=';')

display(df)
# Out:
#                                 #Nome_da_Administradora  \
# 0     ITAÚ ADM DE CONSÓRCIOS LTDA                   ...
# 1     ITAÚ ADM DE CONSÓRCIOS LTDA                   ...
# 2     ITAÚ ADM DE CONSÓRCIOS LTDA                   ...
# 3     ITAÚ ADM DE CONSÓRCIOS LTDA                   ...
# 4     ITAÚ ADM DE CONSÓRCIOS LTDA                   ...
# ...                                                 ...
# 2125  BANRISUL S.A. ADM CONSÓRCIOS                  ...
# 2126  BANRISUL S.A. ADM CONSÓRCIOS                  ...
# 2127  BANRISUL S.A. ADM CONSÓRCIOS                  ...
# 2128  BANRISUL S.A. ADM CONSÓRCIOS                  ...
# 2129  GGS ADM CONS LTDA.                            ...
#
#       CNPJ_da_Administradora  Data_base Código_do_grupo  Código_do_segmento  \
# 0                        776     202310           00040                   1
# 1                        776     202310           00041                   1
# 2                        776     202310           00043                   1
# 3                        776     202310           00044                   1
# 4                        776     202310           00045                   1
# ...                      ...        ...             ...                 ...
# 2125                92692979     202310           10062                   1
# 2126                92692979     202310           10063                   1
# 2127                92692979     202310           10064                   1
# 2128                92692979     202310           10902                   1
# 2129                94187879     202310            4411                   1
#
#       Número_da_assembléia_geral_ordinária Valor_médio_do_bem  \
# 0                                      180          272255,31
# 1                                      180          288848,90
# 2                                      180          269396,83
# 3                                      180          288651,90
# 4                                      180          258187,40
# ...                                    ...                ...
# 2125                                     5          153125,00
# 2126                                     3           87582,78
# 2127                                     2           84259,87
# 2128                                    89          183306,93
# 2129                                   140          138608,62
#
#       Índice_de_correção Taxa_de_administração  Prazo_do_grupo_em_meses  \
# 0                      3              18,65135                      180
# 1                      3              17,21443                      180
# 2                      3              18,29910                      180
# 3                      3              18,35775                      180
# 4                      3              18,75243                      180
# ...                  ...                   ...                      ...
# 2125                   3              16,98270                      200
# 2126                   3              20,00000                      200
# 2127                   3              20,00000                      200
# 2128                  99              12,00000                      180
# 2129                   1              22,31034                      140
#
#       Quantidade_de_cotas_ativas_em_dia  \
# 0                                   373
# 1                                   422
# 2                                   381
# 3                                   385
# 4                                   335
# ...                                 ...
# 2125                                529
# 2126                                489
# 2127                                600
# 2128                                345
# 2129                                 79
#
#       Quantidade_de_cotas_ativas_contempladas_inadimplentes  \
# 0                                                    73
# 1                                                    84
# 2                                                    62
# 3                                                    86
# 4                                                    77
# ...                                                 ...
# 2125                                                  0
# 2126                                                  0
# 2127                                                  0
# 2128                                                  5
# 2129                                                  8
#
#       Quantidade_de_cotas_ativas_não_contempladas_inadimplentes  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 2125                                                 49
# 2126                                                107
# 2127                                                  0
# 2128                                                  0
# 2129                                                  0
#
#       Quantidade_de_cotas_ativas_contempladas_no_mês  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 2125                                               2
# 2126                                               1
# 2127                                               4
# 2128                                               1
# 2129                                               0
#
#       Quantidade_de_cotas_excluídas  Quantidade_de_cotas_ativas_quitadas  \
# 0                              1721                                  431
# 1                              1869                                  493
# 2                              1795                                  433
# 3                              1827                                  456
# 4                              1776                                  393
# ...                             ...                                  ...
# 2125                            166                                    0
# 2126                            101                                    0
# 2127                             45                                    0
# 2128                            258                                   69
# 2129                            312                                   78
#
#       Quantidade_de_cotas_ativas_com_crédito_pendente_de_utilização
# 0                                                    15
# 1                                                    10
# 2                                                    10
# 3                                                    11
# 4                                                    14
# ...                                                 ...
# 2125                                                  8
# 2126                                                  7
# 2127                                                  5
# 2128                                                 66
# 2129                                                  2
#
# [2130 rows x 17 columns]
